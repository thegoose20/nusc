# %% [markdown]
# # Combine Manually Coded Data
# ## Manual Review, part II

# %%
import pandas as pd       # For data analysis
import numpy as np        # For numerical operations
from pathlib import Path  # For writing data and creating directories
import os                 # For reading data files
import config             # For accessing path variables

# %% [markdown]
# ### I. Combine Manually Coded Data Files

# %% [markdown]
# Read all the CSV data files with manual coding.

# %%
coded_path = config.coded_data_path1
csvs = os.listdir(coded_path)
to_remove = ["all_manually_coded_data.csv", ".DS_Store"]
for f in to_remove:
    if f in csvs:
        csvs.remove(f)
print(csvs)
# Out:
# ['CHE_sample_no_preds-manually-checked.csv', 'CPT_sample_no_preds-manually-checked.csv', 'SH_sample_no_preds-manually-checked.csv', 'BXB_sample_no_preds-manually-checked.csv', 'BP_unclassified-manually-checked.csv', 'HL_unclassified-manually-checked.csv', 'WCT_sample_no_preds-manually-checked.csv', 'SW_sample_no_preds-manually-checked.csv', 'OBR_sample_no_preds-manually-checked.csv', 'THS_unclassified-manually-checked.csv']

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
for csv in csvs:
    if "sample" in csv:
        subdf1 = pd.read_csv(coded_path + csv)
        df1 = pd.concat([df1, subdf1])
    else:
        subdf2 = pd.read_csv(coded_path + csv)
        df2 = pd.concat([df2, subdf2])

# %%
df1.rename(columns={
    "Gender bias":"gender_bias", "Unnamed: 1":"index"
    }, inplace=True)
df1.set_index("index", inplace=True)
df1.head(5)
# Out:
#       gender_bias  description_id eadid         rowid         field  \
# index
# 11452         NaN           11452   CHE     CHE/01/01  scopecontent
# 11467         NaN           11467   CHE     CHE/02/04     unittitle
# 11471         NaN           11471   CHE     CHE/02/06     unittitle
# 11554         NaN           11554   CHE  CHE/03/06/12     unittitle
# 11555         NaN           11555   CHE  CHE/03/06/13     unittitle
#
#                                                      doc
# index
# 11452  Drafts and meeting notes relating to the creat...
# 11467                              CHE Supporters Review
# 11471                    Friend Newcastle Annual Reports
# 11554  Collection of documents on sex education in sc...
# 11555  Letters, newsletters and leaflets on the topic...

# %%
df1.gender_bias.value_counts()
# Out:
# gender_bias
# Omission - could we say more about her contribution?                                                                        2
# Omission - could we say more about his contribution?                                                                        2
# Omission - who was Herbert Samuel married to?                                                                               1
# Omission - replace 'her' with name in first instance                                                                        1
# Stereotype - the tone of this biography is different to the others. It is grandiose and frames Reverdy as a male genius.    1
# Omission - missing Charlotte's maiden name. Do we have any more information about her?                                      1
# Omission - missing Cooper's first name                                                                                      1
# Omission - do we know why it was cancelled?                                                                                 1
# Omission - who are 'the contributors'?                                                                                      1
# Omission - could we list which 'women poets' or the titles of the anthologies?                                              1
# Omission - should we say Beverliey Braune?                                                                                  1
# Omission - do we have a surname for Elsie?                                                                                  1
# Omission - is 'Bell' Elsa's surname?                                                                                        1
# Omission - letters from who?                                                                                                1
# Omission - replace 'her' with name                                                                                          1
# Omission - do we know anything more about Ina?                                                                              1
# Omission - can we include a surname for Elsa?                                                                               1
# Omission - can we include a surname for Florence?                                                                           1
# Omission - who is 'she'?                                                                                                    1
# Omission - do we have a surname for the other Mary?                                                                         1
# Omission - do we have a first name for the nurse?                                                                           1
# Omission - can we add first names or initials for Corelli, Austen and Chamberlain?                                          1
# Omission - do we have a maiden name for Elsa?                                                                               1
# Omission - do we have a first name or initial for Fitzmaurice?                                                              1
# Omission - wife is unnamed                                                                                                  1
# Name: count, dtype: int64

# %%
df2.rename(columns={
    "Unnamed: 0":"index", "If yeStereotype, Type?":"type", "gender_bias?":"gender_bias"
    }, inplace=True)
df2.set_index("index", inplace=True)
df2.fillna({"gender_bias": "n"}, inplace=True)
df2.fillna({"type": "NA"}, inplace=True)
df2.head(5)
# Out:
#                                              doc gender_bias type eadid  \
# index
# 0                 'ACERT The First Hundred Days'           n   NA    BP
# 1      'British Housing: Problems and Solutions'           n   NA    BP
# 2                     'Information Booklet' 1989           n   NA    BP
# 3                     'Information Booklet' 1990           n   NA    BP
# 4           'Looking Back Moving Forwards', 1985           n   NA    BP
#
#       description_id            rowid          field
# index
# 0              [186]  ['BP/09/09/03']  ['unittitle']
# 1              [189]  ['BP/09/09/05']  ['unittitle']
# 2              [199]  ['BP/09/09/13']  ['unittitle']
# 3              [203]  ['BP/09/09/17']  ['unittitle']
# 4              [193]  ['BP/09/09/07']  ['unittitle']

# %% [markdown]
# Convert the last three columns' values from strings to lists.

# %%
col_names = ["description_id", "rowid", "field"]
for col_name in col_names:
    new_col = list(df2[col_name])
    new_col = [(col[1:-1]).replace("'", "").split(", ") for col in new_col]
    col_i = list(df2.columns).index(col_name)
    df2.drop(columns=[col_name], inplace=True)
    df2.insert(col_i, col_name, new_col)
df2.head()
# Out:
#                                              doc gender_bias type eadid  \
# index
# 0                 'ACERT The First Hundred Days'           n   NA    BP
# 1      'British Housing: Problems and Solutions'           n   NA    BP
# 2                     'Information Booklet' 1989           n   NA    BP
# 3                     'Information Booklet' 1990           n   NA    BP
# 4           'Looking Back Moving Forwards', 1985           n   NA    BP
#
#       description_id          rowid        field
# index
# 0              [186]  [BP/09/09/03]  [unittitle]
# 1              [189]  [BP/09/09/05]  [unittitle]
# 2              [199]  [BP/09/09/13]  [unittitle]
# 3              [203]  [BP/09/09/17]  [unittitle]
# 4              [193]  [BP/09/09/07]  [unittitle]

# %% [markdown]
# Explode the DataFrame so there's only one description_id per row.

# %%
df2 = df2.explode(["description_id","rowid","field"])
df2.head()
# Out:
#                                              doc gender_bias type eadid  \
# index
# 0                 'ACERT The First Hundred Days'           n   NA    BP
# 1      'British Housing: Problems and Solutions'           n   NA    BP
# 2                     'Information Booklet' 1989           n   NA    BP
# 3                     'Information Booklet' 1990           n   NA    BP
# 4           'Looking Back Moving Forwards', 1985           n   NA    BP
#
#       description_id        rowid      field
# index
# 0                186  BP/09/09/03  unittitle
# 1                189  BP/09/09/05  unittitle
# 2                199  BP/09/09/13  unittitle
# 3                203  BP/09/09/17  unittitle
# 4                193  BP/09/09/07  unittitle

# %% [markdown]
# Standardize the manual coding, with one column for gender bias, one column marking the type of gender bias, and and one column recording any notes about the observed gender bias.

# %%
df1["type"] = df1["gender_bias"].str.split(" - ", expand=True)[0]
df1["note"] = df1["gender_bias"].str.rsplit(" - ", expand=True)[1]
df1 = df1[["doc", "gender_bias", "type", "note", "eadid", "description_id", "rowid", "field"]]
df1.fillna({"gender_bias": "n"}, inplace=True)
df1.fillna({"type": "NA"}, inplace=True)
df1.fillna({"note": "NA"}, inplace=True)
df1.head()
# Out:
#                                                      doc gender_bias type  \
# index
# 11452  Drafts and meeting notes relating to the creat...           n   NA
# 11467                              CHE Supporters Review           n   NA
# 11471                    Friend Newcastle Annual Reports           n   NA
# 11554  Collection of documents on sex education in sc...           n   NA
# 11555  Letters, newsletters and leaflets on the topic...           n   NA
#
#       note eadid  description_id         rowid         field
# index
# 11452   NA   CHE           11452     CHE/01/01  scopecontent
# 11467   NA   CHE           11467     CHE/02/04     unittitle
# 11471   NA   CHE           11471     CHE/02/06     unittitle
# 11554   NA   CHE           11554  CHE/03/06/12     unittitle
# 11555   NA   CHE           11555  CHE/03/06/13     unittitle

# %%
df1.type.value_counts()
# Out:
# type
# NA            678
# Omission       26
# Stereotype      1
# Name: count, dtype: int64

# %%
df1.note.value_counts()
# Out:
# note
# NA                                                                                                             678
# could we say more about her contribution?                                                                        2
# could we say more about his contribution?                                                                        2
# who was Herbert Samuel married to?                                                                               1
# the tone of this biography is different to the others. It is grandiose and frames Reverdy as a male genius.      1
# missing Charlotte's maiden name. Do we have any more information about her?                                      1
# missing Cooper's first name                                                                                      1
# do we know why it was cancelled?                                                                                 1
# who are 'the contributors'?                                                                                      1
# could we list which 'women poets' or the titles of the anthologies?                                              1
# should we say Beverliey Braune?                                                                                  1
# do we have a surname for Elsie?                                                                                  1
# replace 'her' with name in first instance                                                                        1
# is 'Bell' Elsa's surname?                                                                                        1
# replace 'her' with name                                                                                          1
# do we know anything more about Ina?                                                                              1
# can we include a surname for Elsa?                                                                               1
# can we include a surname for Florence?                                                                           1
# who is 'she'?                                                                                                    1
# do we have a surname for the other Mary?                                                                         1
# do we have a first name for the nurse?                                                                           1
# can we add first names or initials for Corelli, Austen and Chamberlain?                                          1
# do we have a maiden name for Elsa?                                                                               1
# do we have a first name or initial for Fitzmaurice?                                                              1
# letters from who?                                                                                                1
# wife is unnamed                                                                                                  1
# Name: count, dtype: int64

# %%
gender_bias_values = list(df1.loc[df1.gender_bias != "n"].gender_bias)
df1 = df1.replace(to_replace=gender_bias_values, value="y")
df1.tail()
# Out:
#                                                      doc gender_bias type  \
# index
# 43357  First draft typescript of 'Laughter When We're...           n   NA
# 43401  Photocopy of chapter from 'Rules of the Game: ...           n   NA
# 43414  Typescript of talk on 'Translating The Birds f...           n   NA
# 43464                        Sheffield Hallam University           n   NA
# 43498  Includes flyers and posters for poetry reading...           n   NA
#
#       note eadid  description_id         rowid         field
# index
# 43357   NA   OBR           43357  OBR/3/2/6/16     unittitle
# 43401   NA   OBR           43401   OBR/3/2/8/6     unittitle
# 43414   NA   OBR           43414   OBR/3/2/9/7     unittitle
# 43464   NA   OBR           43464       OBR/7/3     unittitle
# 43498   NA   OBR           43498     OBR/8/3/3  scopecontent

# %%
df2.insert(column="note", value="NA", loc=3)
df2.head()
# Out:
#                                              doc gender_bias type note eadid  \
# index
# 0                 'ACERT The First Hundred Days'           n   NA   NA    BP
# 1      'British Housing: Problems and Solutions'           n   NA   NA    BP
# 2                     'Information Booklet' 1989           n   NA   NA    BP
# 3                     'Information Booklet' 1990           n   NA   NA    BP
# 4           'Looking Back Moving Forwards', 1985           n   NA   NA    BP
#
#       description_id        rowid      field
# index
# 0                186  BP/09/09/03  unittitle
# 1                189  BP/09/09/05  unittitle
# 2                199  BP/09/09/13  unittitle
# 3                203  BP/09/09/17  unittitle
# 4                193  BP/09/09/07  unittitle

# %%
df = pd.concat([df1, df2])
df.head()
# Out:
#                                                      doc gender_bias type  \
# index
# 11452  Drafts and meeting notes relating to the creat...           n   NA
# 11467                              CHE Supporters Review           n   NA
# 11471                    Friend Newcastle Annual Reports           n   NA
# 11554  Collection of documents on sex education in sc...           n   NA
# 11555  Letters, newsletters and leaflets on the topic...           n   NA
#
#       note eadid description_id         rowid         field
# index
# 11452   NA   CHE          11452     CHE/01/01  scopecontent
# 11467   NA   CHE          11467     CHE/02/04     unittitle
# 11471   NA   CHE          11471     CHE/02/06     unittitle
# 11554   NA   CHE          11554  CHE/03/06/12     unittitle
# 11555   NA   CHE          11555  CHE/03/06/13     unittitle

# %%
df.gender_bias.value_counts()
# Out:
# gender_bias
# n    12287
# y       50
# Name: count, dtype: int64

# %%
df.type.value_counts()
# Out:
# type
# NA                         12287
# Omission                      45
# Sterotype                      2
# Stereotype and Omission        2
# Stereotype                     1
# Name: count, dtype: int64

# %% [markdown]
# ...most of which were *Omission*!

# %%
df.shape
# Out:
# (12337, 8)

# %% [markdown]
# Replace the `type` column with two new columns to each record `"y"` or `"n"` for *Omission* and *Stereotype*.

# %%
type_list = list(df.type)
omission_manual = ["y" if "Omission" in t else "n" for t in type_list]
stereotype_manual = ["y" if "Stereotype" in t else "n" for t in type_list]
# print(type_list[100:150])
# print(omission_manual[100:150])
# print(stereotype_manual[100:150])

# %%
df.insert(column="omission", value=omission_manual, loc=2)
df.insert(column="stereotype", value=stereotype_manual, loc=3)
df.tail()
# Out:
#                                                      doc gender_bias omission  \
# index
# 4861                       “The Way to the Cathedral” I.           n        n
# 4862                      “The Way to the Cathedral” II.           n        n
# 4862                      “The Way to the Cathedral” II.           n        n
# 4863   “Thomas Sharp – an appreciation” by Lewis Keeble.           n        n
# 4864   “Thomas Sharp – an appreciation” by Lewis Keeb...           n        n
#
#       stereotype type note eadid description_id     rowid         field
# index
# 4861           n   NA   NA   THS          32972  THS 61.1     unittitle
# 4862           n   NA   NA   THS          32974  THS 61.2  scopecontent
# 4862           n   NA   NA   THS          32975  THS 61.2     unittitle
# 4863           n   NA   NA   THS          32934  THS 56.2     unittitle
# 4864           n   NA   NA   THS          32933  THS 56.2  scopecontent

# %% [markdown]
# Export the combined manually coded data.

# %%
combined_filename = "all_manually_coded_data.csv"
df.to_csv(config.coded_data_path1+combined_filename)
